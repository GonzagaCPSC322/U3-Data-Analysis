# %%
print("hello")
# Out:
# hello

# %%
print("again!!!")
# Out:
# again!!!

# %% [markdown]
# # This is a Level One Header
# ## This is a Level Two Header
# This is paragraph text
#
# This a hard break
#
# This is a soft break
# Next line
#
# ## Formatting
# **bold** *italics* ~~strikethrough~~ `syntax highlighting`
#
# ```python
# for i in range(5):
#     print(i)
# ```

# %% [markdown]
# ## Lists
# 1. Item 1
# 1. Item 2
#
# * Item A
# * Item B
#
# Nesting
#
# * Ways to run/edit Notebooks
#     1. Locally with VS Code and Jupyter extension
#     1. Locally with Jupyter Notebook (program) or Lab
#     1. Web service like Google Colab

# %% [markdown]
# ## Links and Images
# I recommend [this tutorial](https://www.markdowntutorial.com/)
#
# ![alt text](https://cdn.foliovision.com/images/2017/03/i-love-markdown.png)
#
# <center><img src="https://cdn.foliovision.com/images/2017/03/i-love-markdown.png" width="300"/></center>

# %% [markdown]
# ## Tables
# CarName|ModelYear|MSRP
# -|-|-
# ford pinto|75|2711
# toyota corolla|75|2769

# %% [markdown]
# ## Latex (Math Mode)
# We will use math mode for typesetting math equations
#
# Inline: $y = mx + b$ hello Block (centered): $$y = mx + b$$
#
# See cheat sheet for common latex math mode commands

# %%
import utils
# to force a programmatic reload
import importlib
importlib.reload(utils)

utils.dummy_function()
# Out:
# Hello!!! AGAIN ~~~~dijfaksjf
